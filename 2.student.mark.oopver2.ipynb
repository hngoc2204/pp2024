# %%
class Student:
    def __init__(self, id, name, dob):
        # __ for private, _ for protected
        self.__id= id
        self.__name= name
        self.__dob= dob
    
    def get_id(self):
        return self.__id
    def set_id(self, id):
        self.__id= id

    
    def get_name(self):
        return self.__name
    def set_name(self, name):
        self.__name= name
    
    def get_dob(self):
        return self.__dob
    def set_dob(self, dob):
        self.__dob= dob
    

class Course:
    def __init__(self, id, name):
        self.__id= id
        self.__name= name
    
    def get_id(self):
        return self.__id
    def set_id(self, id):
        self.__id= id

    def get_name(self):
        return self.__name
    def set_name(self, name):
        self.__name= name
        

class StudentMark:
    def __init__(self, course_id, student_id, score):
        self.__course_id= course_id
        self.__student_id= student_id
        self.__score= score

    def get_course_id(self):
        return self.__course_id
    def set_course_id(self, course_id):
        self.__course_id= course_id

    def get_student_id(self):
        return self.__student_id
    def set_student_id(self, student_id):
        self.__student_id= student_id

    def get_score(self):
        return self.__score
    def set_score(self, score):
        self.__score= score
        
def student_num():
    return int(input("The number of students: "))
    
def course_num():
    return int(input("The number of courses: "))
    
def list_course(courses):
    for course in courses:
        print("Course ID: "+ course.get_id)
        print("Course name: "+ course.get_name)
        
def list_student(students):
    for student in students:
        print("Student ID: "+ student.get_id)
        print("Student name: "+ student.get_id)
        print("DoB: "+ student.get_dob)
            
def list_mark(course_id, marks):
    print("Course ID: "+ course_id)
    for mark in marks:
        if mark.set_course_id == course_id: 
            print("Student ID: "+ mark.set_student_id)
            print("Mark: "+ str(mark.set_score))


a= Student.set_id(Student, "23BI14345")
b= Student.set_id(Student, "23BI14296")
c= Student.set_name(Student, "Hngoc")
d= Student.set_name(Student, "Qminh")
student_1= {a,c}
student_2= {b,d}
students= [student_1, student_2]

e= Course.set_id(Course, "FR2.001")
f= Course.set_name(Course, "French 2.001")
g= Course.set_id(Course,"FR2.002")
h= Course.set_id(Course,"French 2.002")
course_1= {e,f}
course_2= {g,h}
courses= [course_1, course_2]


i= StudentMark.set_course_id(StudentMark, "FR2.001")
j= StudentMark.set_student_id(StudentMark, "23BI14345")
k= StudentMark.set_score(StudentMark,20)
l= StudentMark.set_student_id(StudentMark, "23BI14296")
m= StudentMark.set_student_id(StudentMark, "FR2.002")
mark_1= {i,j,k}
mark_2= {i,l,k}
mark_3= {m,j,k}
mark_4= {m,l,k}
marks= [mark_1, mark_2, mark_3, mark_4]

student_num()
course_num()
list_course(courses)
list_student(students)
list_mark("FR2.002", marks)
# Out:
# The number of students:  2
# The number of courses:  2
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 117
#     115 student_num()
#     116 course_num()
# --> 117 list_course(courses)
#     118 list_student(students)
#     119 list_mark("FR2.002", marks)
#
# Cell In[13], line 70, in list_course(courses)
#      68 def list_course(courses):
#      69     for course in courses:
# ---> 70         print("Course ID: "+ course.get_id)
#      71         print("Course name: "+ course.get_name)
#
# AttributeError: 'set' object has no attribute 'get_id'

# %%
class Student:
    def __init__(self, id, name, dob):
        # __ for private, _ for protected
        self.__id= id
        self.__name= name
        self.__dob= dob
    
    def get_id(self):
        return self.__id
    def set_id(self, id):
        self.__id= id

    
    def get_name(self):
        return self.__name
    def set_name(self, name):
        self.__name= name
    
    def get_dob(self):
        return self.__dob
    def set_dob(self, dob):
        self.__dob= dob
    

class Course:
    def __init__(self, id, name):
        self.__id= id
        self.__name= name
    
    def get_id(self):
        return self.__id
    def set_id(self, id):
        self.__id= id

    def get_name(self):
        return self.__name
    def set_name(self, name):
        self.__name= name
        

class StudentMark:
    def __init__(self, course_id, student_id, score):
        self.__course_id= course_id
        self.__student_id= student_id
        self.__score= score

    def get_course_id(self):
        return self.__course_id
    def set_course_id(self, course_id):
        self.__course_id= course_id

    def get_student_id(self):
        return self.__student_id
    def set_student_id(self, student_id):
        self.__student_id= student_id

    def get_score(self):
        return self.__score
    def set_score(self, score):
        self.__score= score
        
def student_num():
    return int(input("The number of students: "))
    
def course_num():
    return int(input("The number of courses: "))
    
def list_course(courses):
    for course in courses:
        print("Course ID: "+ str(course.get_id()))
        print("Course name: "+ str(course.get_name()))
        
def list_student(students):
    for student in students:
        print("Student ID: "+ str(student.get_id()))
        print("Student name: "+ str(student.get_name()))
        print("DoB: "+ str(student.get_dob()))
            
def list_mark(course_id, marks):
    print("Course ID: "+ course_id)
    for mark in marks:
        if str(mark.get_course_id()) == course_id: 
            print("Student ID: "+ str(mark.get_student_id()))
            print("Mark: "+ str(mark.get_score()))

student_1= Student("23BI14345","Hngoc","22/04/2005")
student_2= Student("23BI14296", "Qminh", "06/02/2005")
students= [student_1, student_2]

course_1= Course("FR2.001", "French 2.001")
course_2= Course("FR2.002", "French 2.002")
courses= [course_1, course_2]

mark_1= StudentMark("FR2.001", "23BI14345", 20)
mark_2= StudentMark("FR2.001", "23BI14296", 20)
mark_3= StudentMark("FR2.002", "23BI14345", 20)
mark_4= StudentMark("FR2.002", "23BI14296", 20)
marks= [mark_1, mark_2, mark_3, mark_4]

student_num()
course_num()
list_course(courses)
list_student(students)
list_mark("FR2.002", marks)
# Out:
# The number of students:  2
# The number of courses:  2
# Course ID: FR2.001
# Course name: French 2.001
# Course ID: FR2.002
# Course name: French 2.002
# Student ID: 23BI14345
# Student name: Hngoc
# DoB: 22/04/2005
# Student ID: 23BI14296
# Student name: Qminh
# DoB: 06/02/2005
# Course ID: FR2.002
# Student ID: 23BI14345
# Mark: 20
# Student ID: 23BI14296
# Mark: 20
